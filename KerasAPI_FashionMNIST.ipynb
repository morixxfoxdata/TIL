# %% [markdown]
# <a href="https://colab.research.google.com/github/morixxfoxdata/TIL/blob/main/KerasAPI_FashionMNIST.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from sklearn.model_selection import train_test_split

# %%
# Loading Fashion MNIST data from kerasAPI
(train_images, train_labels), (test_images, test_labels) = tf.keras.datasets.fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 0s 0us/step

# %%
# Checking data shape
print('Train_images:', train_images.shape, 'Test_images:', test_images.shape)
# Out:
# Train_images: (60000, 28, 28) Test_images: (10000, 28, 28)

# %%
# Show some of data
import matplotlib.pyplot as plt
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

plt.figure(figsize=(10, 10))

for i in range(25):
    plt.subplot(5, 5, i+1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(train_images[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[train_labels[i]])
plt.show()

# %%
# Normalization and reshape
train_images = train_images.reshape((60000, 28, 28, 1)).astype('float32') / 255
test_images = test_images.reshape((10000, 28, 28, 1)).astype('float32') / 255

# %%
# split data for training and validation
train_images, val_images, train_labels, val_labels = train_test_split(train_images, train_labels, test_size=0.2, random_state=42)

# %%
# batch_size = 64
# nb_classes = 10
# nb_ephochs = 50
# img_rows, img_cols = 28, 28
# nb_filters = 32
# pool_size = 2
# kernel_size = 3

# %%
model = models.Sequential([
    layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(32, (3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(rate=0.25),
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(rate=0.5),
    layers.Dense(10, activation='softmax')
])

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 26, 26, 32)        320
#
#  max_pooling2d_2 (MaxPoolin  (None, 13, 13, 32)        0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 11, 11, 32)        9248
#
#  max_pooling2d_3 (MaxPoolin  (None, 5, 5, 32)          0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 5, 5, 32)          0
#
#  flatten_1 (Flatten)         (None, 800)               0
#
#  dense_1 (Dense)             (None, 128)               102528
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 113386 (442.91 KB)
# Trainable params: 113386 (442.91 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
train_labels.shape
# Out:
# (48000,)

# %%
history = model.fit(train_images, train_labels, epochs=50,
                    validation_data=(val_images, val_labels),
                    batch_size=64)
# Out:
# Epoch 1/50
# 750/750 [==============================] - 10s 5ms/step - loss: 0.6882 - accuracy: 0.7470 - val_loss: 0.4300 - val_accuracy: 0.8410
# Epoch 2/50
# 750/750 [==============================] - 4s 5ms/step - loss: 0.4610 - accuracy: 0.8347 - val_loss: 0.3640 - val_accuracy: 0.8648
# Epoch 3/50
# 750/750 [==============================] - 4s 5ms/step - loss: 0.4008 - accuracy: 0.8543 - val_loss: 0.3277 - val_accuracy: 0.8770
# Epoch 4/50
# 750/750 [==============================] - 4s 5ms/step - loss: 0.3679 - accuracy: 0.8657 - val_loss: 0.2972 - val_accuracy: 0.8877
# Epoch 5/50
# 750/750 [==============================] - 3s 5ms/step - loss: 0.3439 - accuracy: 0.8760 - val_loss: 0.2867 - val_accuracy: 0.8945
# Epoch 6/50
# 750/750 [==============================] - 4s 6ms/step - loss: 0.3248 - accuracy: 0.8811 - val_loss: 0.2835 - val_accuracy: 0.8913
# Epoch 7/50
# 750/750 [==============================] - 4s 5ms/step - loss: 0.3109 - accuracy: 0.8862 - val_loss: 0.2731 - val_accuracy: 0.8977
# Epoch 8/50
# 750/750 [==============================] - 4s 5ms/step - loss: 0.3013 - accuracy: 0.8903 - val_loss: 0.2723 - val_accuracy: 0.8969
# Epoch 9/50
# 750/750 [==============================] - 5s 6ms/step - loss: 0.2886 - accuracy: 0.8940 - val_loss: 0.2615 - val_accuracy: 0.8990
# Epoch 10/50
# 750/750 [==============================] - 4s 5ms/step - loss: 0.2811 - accuracy: 0.8964 - val_loss: 0.2511 - val_accuracy: 0.9072
# Epoch 11/50
# 750/750 [==============================] - 4s 5ms/step - loss: 0.2709 - accuracy: 0.8994 - val_loss: 0.2555 - val_accuracy: 0.9072
# Epoch 12/50
# 750/750 [==============================] - 5s 7ms/step - loss: 0.2657 - accuracy: 0.9015 - val_loss: 0.2457 - val_accuracy: 0.9054
# Epoch 13/50
# 750/750 [==============================] - 4s 5ms/step - loss: 0.2614 - accuracy: 0.9026 - val_loss: 0.2461 - val_accuracy: 0.9101
# Epoch 14/50
# 750/750 [==============================] - 4s 5ms/step - loss: 0.2578 - accuracy: 0.9045 - val_loss: 0.2426 - val_accuracy: 0.9088
# Epoch 15/50
# 750/750 [==============================] - 4s 6ms/step - loss: 0.2460 - accuracy: 0.9090 - val_loss: 0.2391 - val_accuracy: 0.9087
# Epoch 16/50
# 750/750 [==============================] - 4s 5ms/step - loss: 0.2471 - accuracy: 0.9086 - val_loss: 0.2419 - val_accuracy: 0.9093
# Epoch 17/50
# 750/750 [==============================] - 4s 6ms/step - loss: 0.2404 - accuracy: 0.9097 - val_loss: 0.2431 - val_accuracy: 0.9087
# Epoch 18/50
# 750/750 [==============================] - 4s 6ms/step - loss: 0.2386 - accuracy: 0.9115 - val_loss: 0.2395 - val_accuracy: 0.9106
# Epoch 19/50
# 750/750 [==============================] - 4s 5ms/step - loss: 0.2327 - accuracy: 0.9135 - val_loss: 0.2413 - val_accuracy: 0.9084
# Epoch 20/50
# 750/750 [==============================] - 4s 5ms/step - loss: 0.2302 - accuracy: 0.9126 - val_loss: 0.2481 - val_accuracy: 0.9093
# Epoch 21/50
# 750/750 [==============================] - 4s 5ms/step - loss: 0.2268 - accuracy: 0.9142 - val_loss: 0.2383 - val_accuracy: 0.9122
# Epoch 22/50
# 750/750 [==============================] - 4s 5ms/step - loss: 0.2239 - accuracy: 0.9151 - val_loss: 0.2363 - val_accuracy: 0.9152
# Epoch 23/50
# 750/750 [==============================] - 4s 5ms/step - loss: 0.2237 - accuracy: 0.9164 - val_loss: 0.2416 - val_accuracy: 0.9107
# Epoch 24/50
# 750/750 [==============================] - 4s 5ms/step - loss: 0.2177 - accuracy: 0.9184 - val_loss: 0.2388 - val_accuracy: 0.9104
# Epoch 25/50
# 750/750 [==============================] - 4s 5ms/step - loss: 0.2163 - accuracy: 0.9183 - val_loss: 0.2375 - val_accuracy: 0.9129
# Epoch 26/50
# 750/750 [==============================] - 4s 5ms/step - loss: 0.2148 - accuracy: 0.9200 - val_loss: 0.2389 - val_accuracy: 0.9085
# Epoch 27/50
# 750/750 [==============================] - 3s 5ms/step - loss: 0.2100 - accuracy: 0.9208 - val_loss: 0.2410 - val_accuracy: 0.9099
# Epoch 28/50
# 750/750 [==============================] - 4s 6ms/step - loss: 0.2113 - accuracy: 0.9195 - val_loss: 0.2322 - val_accuracy: 0.9139
# Epoch 29/50
# 750/750 [==============================] - 3s 5ms/step - loss: 0.2085 - accuracy: 0.9211 - val_loss: 0.2301 - val_accuracy: 0.9160
# Epoch 30/50
# 750/750 [==============================] - 4s 5ms/step - loss: 0.2072 - accuracy: 0.9232 - val_loss: 0.2370 - val_accuracy: 0.9113
# Epoch 31/50
# 750/750 [==============================] - 4s 6ms/step - loss: 0.2028 - accuracy: 0.9241 - val_loss: 0.2387 - val_accuracy: 0.9141
# Epoch 32/50
# 750/750 [==============================] - 4s 5ms/step - loss: 0.2016 - accuracy: 0.9250 - val_loss: 0.2335 - val_accuracy: 0.9141
# Epoch 33/50
# 750/750 [==============================] - 4s 5ms/step - loss: 0.1964 - accuracy: 0.9244 - val_loss: 0.2411 - val_accuracy: 0.9118
# Epoch 34/50
# 750/750 [==============================] - 4s 6ms/step - loss: 0.1990 - accuracy: 0.9252 - val_loss: 0.2347 - val_accuracy: 0.9158
# Epoch 35/50
# 750/750 [==============================] - 4s 5ms/step - loss: 0.1948 - accuracy: 0.9273 - val_loss: 0.2292 - val_accuracy: 0.9178
# Epoch 36/50
# 750/750 [==============================] - 3s 5ms/step - loss: 0.1965 - accuracy: 0.9257 - val_loss: 0.2484 - val_accuracy: 0.9096
# Epoch 37/50
# 750/750 [==============================] - 4s 5ms/step - loss: 0.1930 - accuracy: 0.9260 - val_loss: 0.2335 - val_accuracy: 0.9139
# Epoch 38/50
# 750/750 [==============================] - 4s 6ms/step - loss: 0.1892 - accuracy: 0.9292 - val_loss: 0.2352 - val_accuracy: 0.9184
# Epoch 39/50
# 750/750 [==============================] - 3s 5ms/step - loss: 0.1891 - accuracy: 0.9276 - val_loss: 0.2352 - val_accuracy: 0.9145
# Epoch 40/50
# 750/750 [==============================] - 4s 5ms/step - loss: 0.1911 - accuracy: 0.9271 - val_loss: 0.2378 - val_accuracy: 0.9135
# Epoch 41/50
# 750/750 [==============================] - 5s 6ms/step - loss: 0.1872 - accuracy: 0.9293 - val_loss: 0.2288 - val_accuracy: 0.9162
# Epoch 42/50
# 750/750 [==============================] - 4s 5ms/step - loss: 0.1879 - accuracy: 0.9291 - val_loss: 0.2400 - val_accuracy: 0.9126
# Epoch 43/50
# 750/750 [==============================] - 4s 5ms/step - loss: 0.1858 - accuracy: 0.9294 - val_loss: 0.2340 - val_accuracy: 0.9137
# Epoch 44/50
# 750/750 [==============================] - 4s 6ms/step - loss: 0.1842 - accuracy: 0.9299 - val_loss: 0.2443 - val_accuracy: 0.9112
# Epoch 45/50
# 750/750 [==============================] - 3s 5ms/step - loss: 0.1875 - accuracy: 0.9298 - val_loss: 0.2347 - val_accuracy: 0.9168
# Epoch 46/50
# 750/750 [==============================] - 4s 5ms/step - loss: 0.1784 - accuracy: 0.9320 - val_loss: 0.2355 - val_accuracy: 0.9167
# Epoch 47/50
# 750/750 [==============================] - 4s 6ms/step - loss: 0.1803 - accuracy: 0.9300 - val_loss: 0.2392 - val_accuracy: 0.9158
# Epoch 48/50
# 750/750 [==============================] - 4s 5ms/step - loss: 0.1794 - accuracy: 0.9322 - val_loss: 0.2290 - val_accuracy: 0.9178
# Epoch 49/50
# 750/750 [==============================] - 4s 5ms/step - loss: 0.1782 - accuracy: 0.9321 - val_loss: 0.2489 - val_accuracy: 0.9140
# Epoch 50/50
# 750/750 [==============================] - 4s 5ms/step - loss: 0.1808 - accuracy: 0.9302 - val_loss: 0.2400 - val_accuracy: 0.9180

# %%
# モデルの評価
test_loss, test_acc = model.evaluate(test_images, test_labels)
print(f"Test accuracy: {test_acc*100}%")
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.2583 - accuracy: 0.9117
# Test accuracy: 91.17000102996826%

# %%
plt.plot(history.history['accuracy'], label='train_accuracy')
plt.plot(history.history['val_accuracy'], label='validation accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.7, 1])
plt.legend(loc='lower right')
plt.show()
